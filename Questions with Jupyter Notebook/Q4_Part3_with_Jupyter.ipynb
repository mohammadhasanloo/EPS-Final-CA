# %%
#Q4_Part3
library(ggplot2)
library(tidyverse)
library(dplyr)
students_performance <- read.csv("StudentsPerformance.csv")
# Out:
#     X   school sex age Fjob     Mjob     goout internet romantic studytime
# 1    0  GP     F   18  teacher  at_home  4     no       no       2
# 2    1  GP     F   17  other    at_home  3     yes      no       2
# 3    2  GP     F   15  other    at_home  2     yes      no       2
# 4    3  GP     F   15  services health   2     yes      yes      3
# 5    4  GP     F   16  other    other    2     no       no       2
# 6    5  GP     M   16  other    services 2     yes      no       2
# 7    6  GP     M   16  other    other    4     yes      no       2
# 8    7  GP     F   17  teacher  other    4     no       no       2
# 9    8  GP     M   15  other    services 2     yes      no       2
# 10   9  GP     M   15  other    other    1     yes      no       2
# 11  10  GP     F   15  health   teacher  3     yes      no       2
# 12  11  GP     F   15  other    services 2     yes      no       3
# 13  12  GP     M   15  services health   3     yes      no       1
# 14  13  GP     M   15  other    teacher  3     yes      no       2
# 15  14  GP     M   15  other    other    2     yes      yes      3
# 16  15  GP     F   16  other    health   4     yes      no       1
# 17  16  GP     F   16  services services 3     yes      no       3
# 18  17  GP     F   16  other    other    2     no       no       2
# 19  18  GP     M   17  services services 5     yes      no       1
# 20  19  GP     M   16  other    health   3     yes      no       1
# 21  20  GP     M   15  other    teacher  1     yes      no       2
# 22  21  GP     M   15  health   health   2     yes      no       1
# 23  22  GP     M   16  other    teacher  1     yes      no       2
# 24  23  GP     M   16  other    other    4     yes      no       2
# 25  24  GP     F   15  health   services 2     yes      no       3
# 26  25  GP     F   16  services services 2     yes      no       1
# 27  26  GP     M   15  other    other    2     yes      no       1
# 28  27  GP     M   15  services health   4     yes      no       1
# 29  28  GP     M   16  other    services 3     yes      no       2
# 30  29  GP     M   16  teacher  teacher  5     yes      yes      2
# ... ... ...    ... ... ...      ...      ...   ...      ...      ...
# 366 365 MS     M   18  other    at_home  4     no       no       2
# 367 366 MS     M   18  services teacher  2     yes      yes      3
# 368 367 MS     F   17  services other    1     yes      yes      1
# 369 368 MS     F   18  services at_home  3     yes      yes      1
# 370 369 MS     F   18  teacher  other    2     yes      yes      2
# 371 370 MS     F   19  services services 2     no       yes      2
# 372 371 MS     M   18  services at_home  3     yes      yes      1
# 373 372 MS     F   17  at_home  other    3     no       yes      3
# 374 373 MS     F   17  other    other    5     yes      no       1
# 375 374 MS     F   18  other    other    4     yes      no       3
# 376 375 MS     F   18  other    other    2     yes      no       3
# 377 376 MS     F   20  other    health   3     yes      yes      3
# 378 377 MS     F   18  services teacher  3     yes      no       2
# 379 378 MS     F   18  other    other    3     yes      yes      2
# 380 379 MS     F   17  other    at_home  4     yes      no       2
# 381 380 MS     M   18  teacher  teacher  4     yes      no       2
# 382 381 MS     M   18  other    other    3     yes      yes      1
# 383 382 MS     M   17  services other    3     yes      no       2
# 384 383 MS     M   19  services other    2     no       no       1
# 385 384 MS     M   18  other    other    3     no       no       1
# 386 385 MS     F   18  other    at_home  3     no       no       3
# 387 386 MS     F   18  at_home  teacher  3     yes      yes      1
# 388 387 MS     F   19  other    services 2     yes      no       3
# 389 388 MS     F   18  services teacher  4     yes      no       2
# 390 389 MS     F   18  other    other    1     no       no       2
# 391 390 MS     M   20  services services 4     no       no       2
# 392 391 MS     M   17  services services 5     yes      no       1
# 393 392 MS     M   21  other    other    3     no       no       1
# 394 393 MS     M   18  other    services 1     yes      no       1
# 395 394 MS     M   19  at_home  other    3     yes      no       1
#     failures health absences G1        G2        G3
# 1   0        3       6        5.000000  7.529856  9.289229
# 2   0        3       4        5.000000  7.192039  9.424835
# 3   3        3      10        3.807703  8.000000  7.354029
# 4   0        5       2       15.000000 16.373208 17.796916
# 5   0        5       4        6.000000 12.138542 12.800024
# 6   0        5      10       15.000000 16.804680 18.347259
# 7   0        3       0       12.000000 13.691091 14.187810
# 8   0        1       6        6.000000  6.794185  9.012740
# 9   0        1       0       16.000000 19.852952 20.000000
# 10  0        5       0       14.000000 17.180466 18.073614
# 11  0        2       0       10.000000  9.609179 11.950918
# 12  0        4       4       10.000000 14.612980 15.104784
# 13  0        5       2       14.000000 16.114536 16.478890
# 14  0        3       2       10.000000 11.908667 14.224962
# 15  0        3       0       14.000000 17.247266 19.099868
# 16  0        2       4       14.000000 15.830156 16.846808
# 17  0        2       6       13.000000 16.108698 16.747565
# 18  0        4       4        8.000000 11.777374 12.983365
# 19  3        5      16        3.048116  5.000000  2.801006
# 20  0        5       4        8.000000 12.054892 13.130371
# 21  0        1       0       13.000000 15.839844 18.165873
# 22  0        5       0       12.000000 16.881585 17.804570
# 23  0        5       2       15.000000 17.167003 19.764039
# 24  0        5       0       13.000000 15.010068 15.364088
# 25  0        5       2       10.000000 10.852908 10.733871
# 26  2        5      14        6.000000  9.000000  8.000000
# 27  0        5       2       12.000000 13.997857 13.913669
# 28  0        1       4       15.000000 18.273986 17.496194
# 29  0        5       4       11.000000 12.805237 14.497028
# 30  0        5      16       10.000000 13.767295 13.874503
# ... ...      ...    ...      ...       ...       ...
# 366 0        3       4       10.000000 12.151830 13.144225
# 367 0        5       0       13.000000 15.201160 15.725049
# 368 1        1       0        7.000000  6.000000  0.000000
# 369 0        4       0       11.000000 11.756780 13.367580
# 370 0        5      10       14.000000 14.349443 14.084553
# 371 2        3       4        7.000000  7.000000  9.000000
# 372 0        3       3       14.000000 14.375829 14.779999
# 373 0        3       8       13.000000 12.831596 13.563347
# 374 0        1      14        6.000000  6.778127  8.271603
# 375 0        1       0       19.000000 19.824934 20.000000
# 376 0        4       2        8.000000  9.973049 12.393107
# 377 2        3       4       15.000000 14.000000 15.000000
# 378 0        2       4        8.000000 10.525745 12.674909
# 379 0        1       0       15.000000 16.744031 18.197867
# 380 0        1      17       10.000000 11.994416 12.916115
# 381 0        2       4       15.000000 16.038878 16.532673
# 382 0        5       5        7.000000  7.584805 10.138719
# 383 0        3       2       11.000000 13.089595 13.067702
# 384 1        5       0        6.000000  5.000000  0.000000
# 385 1        3      14        6.000000  5.000000  5.000000
# 386 0        4       2       10.000000 11.311083 12.562760
# 387 0        5       7        6.000000  7.256775  9.083873
# 388 1        5       0        7.000000  5.000000  0.000000
# 389 0        1       0        7.000000 11.004114 11.255521
# 390 1        5       0        6.000000  5.000000  0.000000
# 391 2        4      11        9.000000  9.000000  9.000000
# 392 0        2       3       14.000000 18.038613 18.700771
# 393 3        3       3        6.729288  8.000000  4.287731
# 394 0        5       0       11.000000 13.470672 13.429538
# 395 0        5       5        8.000000 10.732965 11.767275

# %%
#Parta
students_performance_sample <- ggplot(students_performance, aes(x = failures, y = (G1 + G2 + G3)/3)) + geom_point(col = "black")

students_performance_sample
# Out:
# plot without title

# %%
correlation_coefficient = cor((students_performance["G1"] + students_performance["G2"] + students_performance["G3"])/3, students_performance["G1"])
correlation_coefficient

# %%
students_performance_sample <- ggplot(students_performance, aes(x = G1, y = (G1 + G2 + G3)/3)) + geom_point(col = "black")

students_performance_sample
# Out:
# plot without title

# %%
correlation_coefficient = cor((students_performance["G1"] + students_performance["G2"] + students_performance["G3"])/3, students_performance["G1"])
correlation_coefficient
# Out:
# Error in `[.data.frame`(StudentsPerformance, "(G1 + G2 + G3)/3)"): undefined columns selected
# Traceback:
#
# 1. cor(StudentsPerformance["(G1 + G2 + G3)/3)"], StudentsPerformance["G1"])
# 2. is.data.frame(x)
# 3. StudentsPerformance["(G1 + G2 + G3)/3)"]
# 4. `[.data.frame`(StudentsPerformance, "(G1 + G2 + G3)/3)")
# 5. stop("undefined columns selected")
